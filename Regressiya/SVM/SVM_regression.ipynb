# %%
from sklearn.svm import SVR
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(2)
X = np.linspace(0, 24, 100).reshape(-1, 1)  # 0 dan 24 soatgacha
y = 10 + 10 * np.sin((X.ravel() - 6) * np.pi / 12) + np.random.normal(0, 1, 100)  # kundalik harorat model

# %%
svm = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=0.5)

# %%
svm.fit(X, y)
# Out:
# SVR(C=100, epsilon=0.5, gamma=0.1)

# %%
y_pred = svm.predict(X)

# %%
plt.figure(figsize=(10, 5))
plt.plot(X, y, label='Haqiqiy harorat', color='lightblue')
plt.plot(X, y_pred, color='blue', label='SVM Regression')
plt.xlabel("Soat")
plt.ylabel("Harorat (°C)")
plt.title("SVM Regression: Haroratni kun davomida bashorat qilish")
plt.legend()
plt.grid(True)
plt.show()
